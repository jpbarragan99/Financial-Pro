# %%
#Question 2 Task 1

import pandas as pd
import matplotlib.pyplot as plt

var = pd.read_excel("CORRECTION.xlsx")
print(var)

x = list(var['FORECAST'])
y = list(var['HOUSING1'])

plt.figure(figsize=(10,10))
plt.style.use('seaborn')
plt.scatter(x,y,marker="o",s=100,edgecolors="black",c="red")
plt.title("Housing")
plt.show()
# Out:
#       YEAR  QUARTER  HOUSING1  FORECAST  FORECASTR  Quarterly Changes
# 0   2010.0      1.0      0.55     0.600      -0.40          -3.333333
# 1   2010.0      2.0      0.62     0.580      -0.42          -3.448276
# 2   2010.0      3.0      0.60     0.560      -0.44          -1.785714
# 3   2010.0      4.0      0.59     0.550      -0.45           3.636364
# 4   2011.0      1.0      0.54     0.570      -0.43           3.508772
# 5   2011.0      2.0      0.56     0.590      -0.41          11.864407
# 6   2011.0      3.0      0.58     0.660      -0.34           7.575758
# 7   2011.0      4.0      0.62     0.710      -0.29           4.225352
# 8   2012.0      1.0      0.66     0.740      -0.26          20.270270
# 9   2012.0      1.0      0.66     0.890      -0.11           3.370787
# 10  2012.0      2.0      0.69     0.920      -0.08          -3.260870
# 11  2012.0      3.0      0.74     0.890      -0.11           7.865169
# 12  2012.0      4.0      0.79     0.960      -0.04           0.000000
# 13  2013.0      1.0      0.90     0.960      -0.04           3.125000
# 14  2013.0      2.0      0.97     0.990      -0.01           5.050505
# 15  2013.0      2.0      0.97     1.040       0.04          -0.961538
# 16  2013.0      3.0      0.87     1.030       0.03          10.679612
# 17  2013.0      4.0      0.89     1.140       0.14           0.877193
# 18  2014.0      1.0      1.00     1.150       0.15          -0.869565
# 19  2014.0      2.0      0.92     1.140       0.14           4.385965
# 20  2014.0      3.0      0.98     1.190       0.19           0.000000
# 21  2014.0      4.0      1.02     1.190       0.19          -5.042017
# 22  2015.0      1.0      1.08     1.130       0.13         -12.389381
# 23  2015.0      2.0      0.97     0.990      -0.01          17.171717
# 24  2015.0      3.0      1.14     1.160       0.16           3.448276
# 25  2015.0      4.0      1.16     1.200       0.20           0.000000
# 26  2016.0      1.0      1.13     1.200       0.20          -5.000000
# 27  2016.0      2.0      1.13     1.140       0.14           4.385965
# 28  2016.0      3.0      1.16     1.190       0.19          -3.361345
# 29  2016.0      4.0      1.14     1.150       0.15          21.739130
# 30  2017.0      1.0      1.22     1.400       0.40          -7.142857
# 31  2017.0      2.0      1.25     1.300       0.30          -9.230769
# 32  2017.0      3.0      1.16     1.180       0.18           0.847458
# 33  2017.0      4.0      1.17     1.190       0.19           5.882353
# 34  2018.0      1.0      1.25     1.260       0.26           2.380952
# 35  2018.0      2.0      1.32     1.290       0.29          -4.651163
# 36  2018.0      3.0      1.26     1.230       0.23          -8.130081
# 37  2018.0      4.0      1.22     1.130       0.13                NaN
# 38     NaN      NaN       NaN       NaN        NaN                NaN
# 39     NaN      NaN       NaN     1.005        NaN                NaN

# %%
def variance(data):
    n = len(data)
    mean = sum(data) / n
    deviations = [(x - mean) ** 2 for x in data]
    variance = sum(deviations) / n
    return variance

variance(list(var['FORECAST']))
# Out:
# 0.059551315789473674

# %%
var2 = pd.read_excel("CORRECTION.xlsx")

x1 = list(var2['FORECASTR'])
y1 = list(var2['FORECAST'])

plt.figure(figsize=(10,10))
plt.style.use('seaborn')
plt.scatter(x1,y1,marker="o",s=100,edgecolors="black",c="blue")
plt.title("Housing")
plt.show()
